# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 equals 4.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# A train departs from City A heading to City B at a speed of 60 miles per hour. At the same time, another train departs from City B heading to City A at a speed of 90 miles per hour. The distance between City A and City B is 300 miles. How far from City A will the two trains meet?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# To find the distance from City A where the two trains meet, we can use the concept of relative speed and the total distance between the two cities.
#
# 1. Let's denote:
#    - Speed of Train A (from City A to City B) = 60 miles per hour
#    - Speed of Train B (from City B to City A) = 90 miles per hour
#    - Total distance between City A and City B = 300 miles
#
# 2. The combined speed of the two trains is:
#    \[
#    \text{Combined speed} = 60 \text{ mph} + 90 \text{ mph} = 150 \text{ mph}
#    \]
#
# 3. To find the time until they meet, we can use the formula:
#    \[
#    \text{Time} = \frac{\text{Distance}}{\text{Speed}}
#    \]
#    Here, the distance is 300 miles, and the combined speed is 150 miles per hour:
#    \[
#    \text{Time} = \frac{300 \text{ miles}}{150 \text{ mph}} = 2 \text{ hours}
#    \]
#
# 4. Now, we need to find out how far each train travels in that time:
#    - Distance traveled by Train A in 2 hours:
#    \[
#    \text{Distance} = \text{Speed} \times \text{Time} = 60 \text{ mph} \times 2 \text{ hours} = 120 \text{ miles}
#    \]
#    - Distance traveled by Train B in 2 hours:
#    \[
#    \text{Distance} = 90 \text{ mph} \times 2 \text{ hours} = 180 \text{ miles}
#    \]
#
# 5. Therefore, the two trains meet 120 miles from City A.
#
# Thus, the distance from City A where the two trains meet is **120 miles**.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# To find the distance from City A where the two trains meet, we can use the concept of relative speed and the total distance between the two cities.
#
# 1. Let's denote:
#    - Speed of Train A (from City A to City B) = 60 miles per hour
#    - Speed of Train B (from City B to City A) = 90 miles per hour
#    - Total distance between City A and City B = 300 miles
#
# 2. The combined speed of the two trains is:
#    \[
#    \text{Combined speed} = 60 \text{ mph} + 90 \text{ mph} = 150 \text{ mph}
#    \]
#
# 3. To find the time until they meet, we can use the formula:
#    \[
#    \text{Time} = \frac{\text{Distance}}{\text{Speed}}
#    \]
#    Here, the distance is 300 miles, and the combined speed is 150 miles per hour:
#    \[
#    \text{Time} = \frac{300 \text{ miles}}{150 \text{ mph}} = 2 \text{ hours}
#    \]
#
# 4. Now, we need to find out how far each train travels in that time:
#    - Distance traveled by Train A in 2 hours:
#    \[
#    \text{Distance} = \text{Speed} \times \text{Time} = 60 \text{ mph} \times 2 \text{ hours} = 120 \text{ miles}
#    \]
#    - Distance traveled by Train B in 2 hours:
#    \[
#    \text{Distance} = 90 \text{ mph} \times 2 \text{ hours} = 180 \text{ miles}
#    \]
#
# 5. Therefore, the two trains meet 120 miles from City A.
#
# Thus, the distance from City A where the two trains meet is **120 miles**.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

from dotenv import load_dotenv
from openai import OpenAI

load_dotenv(override=True)

openai = OpenAI()


messages = [{"role": "user", "content": "Help pick a business area that might be worth exploring for an Agentic AI opportunity within India."}]

# Then make the first call:

response =  openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)


# Then read the business idea:

business_idea = response.choices[0].message.content
print("business_idea :",business_idea)

# And repeat! In the next message, include the business idea within the message
question = f"Please propose a pain-point in the {business_idea} industry. Respond only with the pain-point."

messages = [{"role": "user", "content": question}]

response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

answer = response.choices[0].message.content
print("pain_point :", answer)


question = f"Please provide the solution to the pain-point in the {business_idea} industry."

messages = [{"role": "user", "content": question}]

response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

answer1 = response.choices[0].message.content
print("solution :", answer1)
# Out:
# business_idea : Exploring Agentic AI opportunities in India presents a unique chance to leverage advancements in AI technology while addressing specific needs in the market. Here are a few promising business areas worth considering:
#
# 1. **Healthcare and Telemedicine**:
#    - **Personalized Medicine**: Develop AI agents that provide personalized health recommendations, track patient data, and assist in disease prediction and prevention.
#    - **Virtual Health Assistants**: Create AI-driven bots that can assist patients with scheduling appointments, medication reminders, and providing basic health advice.
#
# 2. **Education Technology (EdTech)**:
#    - **Adaptive Learning Platforms**: Create AI systems that can adapt learning material based on individual student performance and preferences, offering personalized educational experiences.
#    - **AI Tutors**: Design intelligent tutoring systems that can engage with students in real-time, providing support in various subjects and languages.
#
# 3. **Agriculture**:
#    - **Precision Farming Solutions**: Develop AI agents that analyze data from IoT devices in agricultural fields to provide farmers with actionable insights on crop health, yield predictions, and resource management.
#    - **Supply Chain Optimization**: Create AI tools that help farmers connect directly with consumers or retailers, streamlining the supply chain and reducing food waste.
#
# 4. **Finance and FinTech**:
#    - **Personal Finance Management**: Build AI agents that assist individuals in budgeting, investment planning, and financial risk assessment, particularly for younger generations or underserved markets.
#    - **Fraud Detection**: Implement AI systems that monitor transactional data to detect and prevent fraudulent activities in real-time.
#
# 5. **Smart Cities and Urban Development**:
#    - **Traffic Management Systems**: Develop AI-based solutions to optimize traffic flow, manage public transportation systems, and reduce congestion in rapidly growing urban areas.
#    - **Waste Management**: Utilize AI to enhance waste collection routes, promoting efficient recycling and disposal in urban environments.
#
# 6. **Retail and E-Commerce**:
#    - **Personalized Shopping Experiences**: Create agentic AI that enhances the shopping experience with personalized recommendations based on user behavior and preferences.
#    - **Customer Service Automation**: Develop intelligent chatbots and virtual assistants that can handle customer queries and support across various platforms.
#
# 7. **Real Estate**:
#    - **AI-Driven Property Management**: Create solutions that analyze market trends, property values, and customer preferences to assist in buying, selling, and renting properties.
#    - **Virtual Tours and Experiences**: Develop AI-enhanced platforms that offer potential buyers immersive virtual tours of properties.
#
# 8. **Legal Tech**:
#    - **Document Automation and Analysis**: Build AI systems to assist law firms and legal departments with automated drafting, contract analysis, and legal research.
#    - **AI-Powered Legal Assistants**: Develop tools that provide legal advice or research assistance, making legal services more accessible.
#
# Before pursuing an Agentic AI opportunity, it’s essential to validate the market need, assess regulatory considerations, understand technological feasibility, and consider cultural nuances that may impact adoption in the chosen area. Collaborative partnerships with local stakeholders can also enhance the chances of success in these ventures.
# pain_point : Limited digital literacy and access to technology in certain demographics, particularly in rural areas, may hinder the adoption and effectiveness of AI solutions across sectors such as healthcare, education, and agriculture in India.
# solution : To address the pain points associated with exploring Agentic AI opportunities in India across various sectors, a structured approach can help you systematically understand and tackle challenges while maximizing the potential of AI technologies. Here’s a comprehensive solution breakdown for each identified opportunity:
#
# ### 1. Healthcare and Telemedicine
#
# **Pain Points**:
# - Data privacy concerns, lack of infrastructure, and varying access to healthcare.
#
# **Solutions**:
# - **Regulatory Compliance**: Ensure adherence to India's data protection laws (like the Personal Data Protection Bill) while implementing technology.
# - **Infrastructure Partnerships**: Collaborate with local healthcare facilities to pilot AI solutions, facilitating better integration into existing systems.
# - **User Education**: Develop training programs for patients and practitioners to ensure familiarity with AI tools.
#
# ### 2. Education Technology (EdTech)
#
# **Pain Points**:
# - Diverse learning styles and socioeconomic barriers to access.
#
# **Solutions**:
# - **Localized Content Creation**: Develop adaptive learning platforms in multiple languages to cater to a wider audience.
# - **Affordability Models**: Introduce subscription models or partnerships with governments and NGOs to subsidize costs for low-income students.
#
# ### 3. Agriculture
#
# **Pain Points**:
# - Knowledge gaps among farmers and varying technology adoption rates.
#
# **Solutions**:
# - **Community Outreach**: Implement training sessions and workshops to demonstrate the value of precision farming technologies.
# - **Mobile Access**: Create mobile-friendly platforms that provide farmers with real-time data and insights using simple interfaces.
#
# ### 4. Finance and FinTech
#
# **Pain Points**:
# - Trust issues with financial institutions and complexity of financial products.
#
# **Solutions**:
# - **Transparent Algorithms**: Use explainable AI to help users understand financial recommendations, enhancing trust.
# - **Community Education Programs**: Focus on financial literacy programs aimed at younger populations to promote responsible financial behaviors.
#
# ### 5. Smart Cities and Urban Development
#
# **Pain Points**:
# - Rapid urbanization and outdated infrastructure.
#
# **Solutions**:
# - **Pilot Projects**: Start with pilot smart city initiatives in select urban areas to demonstrate effectiveness and scalability.
# - **Public Engagement**: Involve citizens in the planning process for transportation and waste management systems to ensure solutions meet community needs.
#
# ### 6. Retail and E-Commerce
#
# **Pain Points**:
# - High competition and varying consumer behaviors.
#
# **Solutions**:
# - **Dynamic Pricing Models**: Implement AI-driven pricing strategies that adapt to market changes and inventory levels.
# - **Local Delivery Partnerships**: Collaborate with local delivery services to improve logistics and enhance the shopping experience.
#
# ### 7. Real Estate
#
# **Pain Points**:
# - Fragmented real estate markets and lack of user-friendly property technology.
#
# **Solutions**:
# - **Unified Platforms**: Develop a comprehensive platform that aggregates listings while providing users with valuable insights.
# - **Augmented Reality Features**: Utilize AR technologies to provide immersive property experiences beyond traditional virtual tours.
#
# ### 8. Legal Tech
#
# **Pain Points**:
# - Limited access to affordable legal services and document handling inefficiencies.
#
# **Solutions**:
# - **Freemium Models**: Offer basic legal advice and document automation free of charge, with options for premium services.
# - **Legal Education Initiatives**: Partner with educational institutions to provide training on the use of legal tech tools for law students and professionals.
#
# ### General Considerations
#
# 1. **Market Validation**: Conduct comprehensive market research to assess real needs and pain points through surveys, focus groups, and pilot projects.
#
# 2. **Regulatory Advocacy**: Engage with policymakers to establish conducive regulations that facilitate the adoption of AI solutions across sectors.
#
# 3. **Local Stakeholder Partnerships**: Build relationships with NGOs, government agencies, and local enterprises to foster trust and enhance community engagement.
#
# 4. **Cultural Sensitivity**: Be mindful of cultural differences and regional peculiarities while deploying AI solutions, leading to higher acceptance and better user experience.
#
# 5. **Phased Rollouts**: Start with controlled local markets or specific demographics to test solutions before a wider rollout, minimizing risks.
#
# By addressing these factors and implementing tailored solutions, you can effectively leverage Agentic AI technologies across various sectors in India, ensuring that they meet local needs and contribute to sustainable growth.
